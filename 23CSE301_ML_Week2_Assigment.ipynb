# %% [markdown]
# **Enter your code for Exercise 1 in the following cells (add as many cell as you need)**
#
# ---

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\subim\data-manipulation-visualization-subikshabamboo\Iris.csv")

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df[(df['SepalLengthCm']>6.0)&(df['SepalLengthCm']<6.5)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 51    52            6.4           3.2            4.5           1.5
# 56    57            6.3           3.3            4.7           1.6
# 63    64            6.1           2.9            4.7           1.4
# 68    69            6.2           2.2            4.5           1.5
# 71    72            6.1           2.8            4.0           1.3
# 72    73            6.3           2.5            4.9           1.5
# 73    74            6.1           2.8            4.7           1.2
# 74    75            6.4           2.9            4.3           1.3
# 87    88            6.3           2.3            4.4           1.3
# 91    92            6.1           3.0            4.6           1.4
# 97    98            6.2           2.9            4.3           1.3
# 100  101            6.3           3.3            6.0           2.5
# 103  104            6.3           2.9            5.6           1.8
# ...

# %%
df['SepalArea']=df['SepalLengthCm']*df['SepalWidthCm']
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  SepalArea
# 0       Iris-setosa      17.85
# 1       Iris-setosa      14.70
# 2       Iris-setosa      15.04
# 3       Iris-setosa      14.26
# ...

# %%
grouped = df.groupby('Species')

mean=grouped.mean(numeric_only=True)
print(mean)
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm  SepalArea
# Species
# Iris-setosa             0.244    17.2088
# Iris-versicolor         1.326    16.5262
# Iris-virginica          2.026    19.6846

# %%
df.sort_values('SepalArea',ascending=False)
df.sort_values(by=['SepalLengthCm','PetalLengthCm'],ascending=[False,False])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 135  136            7.7           3.0            6.1           2.3
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 42    43            4.4           3.2            1.3           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#             Species  SepalArea
# 131  Iris-virginica      30.02
# 118  Iris-virginica      20.02
# 117  Iris-virginica      29.26
# 122  Iris-virginica      21.56
# ...

# %%
#df['PetalLengthCm'].fillna(df['PetalLengthCm'].mean(), inplace=True)
df.dropna(subset=['PetalLengthCm'])
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# SepalArea        0
# dtype: int64

# %%
df.to_csv('ass1.csv',index=False)

# %% [markdown]
# **Enter your code for Exercise 2 in the following cells (add as many cell as you need)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset('titanic')
sns.violinplot(x='embarked',y='age',data=df)
plt.show()

# %%
sns.boxplot(x='pclass',y='fare',data=df)
plt.show()
#print(df.columns.tolist())

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='age',y='fare',data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_df=df.select_dtypes(include=['number'])
sns.heatmap(num_df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df[['age','survived','fare']],hue='survived')
plt.show()
